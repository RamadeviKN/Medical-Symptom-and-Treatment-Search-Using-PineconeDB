# %%
# %load_ext dotenv
# %dotenv

# %%
import pandas as pd
import os
from pinecone import Pinecone, ServerlessSpec
from dotenv import load_dotenv, find_dotenv
import pinecone
from sentence_transformers import SentenceTransformer

# %%
symptom_df = pd.read_csv("../data/preprocessed_symptom_dataset.csv", encoding = "cp1252")

# %%
# Create a unique identifier for each section combining course_id and section_id
symptom_df['unique_id'] = symptom_df['disease'].astype(str) + '-' + symptom_df['symptom'].astype(str)

# %%
# Create metadata for each section
symptom_df['metadata'] = symptom_df.apply(lambda row: {
    "disease": row['disease'],
    "symptom": row['symptom'],
    "description": row['description'],
    "weight": row['weight'],
    "precautions": row['precautions'] if isinstance(row['precautions'], list) else []
}, axis=1)

# %%
weights = {
    'disease': 2.0,
    'symptom': 1.5,
    'description': 1.0,
    'precautions': 1.0
}

# %%
# Initialize the model
model = SentenceTransformer('multi-qa-distilbert-cos-v1')

# %%
def create_embeddings(row, model, weights):
    """
    Create a combined embedding for a metadata row.
    
    Parameters:
    - row: A row of the dataframe.
    - model: The embedding model used for encoding.
    - weights: A dictionary of weights for individual fields.
    
    Returns:
    - A combined embedding vector.
    """
    # Extract weights
    weight_disease = weights.get('disease', 2.0)
    weight_symptom = weights.get('symptom', 1.5)
    weight_description = weights.get('description', 1.0)
    weight_precautions = weights.get('precautions', 1.0)

    # Encode individual components
    emb_disease = model.encode(row['disease'], show_progress_bar=False) * weight_disease
    emb_symptom = model.encode(row['symptom'], show_progress_bar=False) * weight_symptom * row['weight']  # Incorporate symptom weight
    emb_description = model.encode(row['description'], show_progress_bar=False) * weight_description
    print(f"Row precautions: {row['precautions']}")

    # Handle precautions as a list
    if isinstance(row['precautions'], list) and len(row['precautions']) > 0:
        emb_precautions = sum(model.encode(precaution, show_progress_bar=False) for precaution in row['precautions']) * weight_precautions
    else:
        # If precautions is missing or an empty list
        emb_precautions = model.encode('No Precautions Available', show_progress_bar=False) * weight_precautions

    # Combine embeddings by averaging them
    combined_embedding = (emb_disease + emb_symptom + emb_description + emb_precautions) / \
                         (weight_disease + weight_symptom* row['weight'] + weight_description + weight_precautions)
    
    return combined_embedding

# %%
# Apply the method
symptom_df['embedding'] = symptom_df.apply(lambda row: create_embeddings(row, model, weights), axis=1)
# Out:
# Row precautions: ['lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax']
# Row precautions: ['lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax']
# Row precautions: ['lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax']
# Row precautions: ['lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax']
# Row precautions: ['lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax']
# Row precautions: ['lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax']
# Row precautions: ['bath twice', 'avoid fatty spicy food', 'drink plenty of water', 'avoid too many products']
# Row precautions: ['bath twice', 'avoid fatty spicy food', 'drink plenty of water', 'avoid too many products']
# Row precautions: ['bath twice', 'avoid fatty spicy food', 'drink plenty of water', 'avoid too many products']
# Row precautions: ['bath twice', 'avoid fatty spicy food', 'drink plenty of water', 'avoid too many products']
# Row precautions: ['avoid open cuts', 'wear ppe if possible', 'consult doctor', 'follow up']
# Row precautions: ['avoid open cuts', 'wear ppe if possible', 'consult doctor', 'follow up']
# Row precautions: ['avoid open cuts', 'wear ppe if possible', 'consult doctor', 'follow up']
# Row precautions: ['avoid open cuts', 'wear ppe if possible', 'consult doctor', 'follow up']
# Row precautions: ['stop alcohol consumption', 'consult doctor', 'medication', 'follow up']
# Row precautions: ['stop alcohol consumption', 'consult doctor', 'medication', 'follow up']
# Row precautions: ['stop alcohol consumption', 'consult doctor', 'medication', 'follow up']
# Row precautions: ['stop alcohol consumption', 'consult doctor', 'medication', 'follow up']
# Row precautions: ['stop alcohol consumption', 'consult doctor', 'medication', 'follow up']
# Row precautions: ['stop alcohol consumption', 'consult doctor', 'medication', 'follow up']
# Row precautions: ['stop alcohol consumption', 'consult doctor', 'medication', 'follow up']
# Row precautions: ['apply calamine', 'cover area with bandage', 'use ice to compress itching']
# Row precautions: ['apply calamine', 'cover area with bandage', 'use ice to compress itching']
# Row precautions: ['apply calamine', 'cover area with bandage', 'use ice to compress itching']
# Row precautions: ['apply calamine', 'cover area with bandage', 'use ice to compress itching']
# Row precautions: ['exercise', 'use hot and cold therapy', 'try acupuncture', 'massage']
# Row precautions: ['exercise', 'use hot and cold therapy', 'try acupuncture', 'massage']
# Row precautions: ['exercise', 'use hot and cold therapy', 'try acupuncture', 'massage']
# Row precautions: ['exercise', 'use hot and cold therapy', 'try acupuncture', 'massage']
# Row precautions: ['exercise', 'use hot and cold therapy', 'try acupuncture', 'massage']
# Row precautions: ['switch to loose cloothing', 'take deep breaths', 'get away from trigger', 'seek help']
# Row precautions: ['switch to loose cloothing', 'take deep breaths', 'get away from trigger', 'seek help']
# Row precautions: ['switch to loose cloothing', 'take deep breaths', 'get away from trigger', 'seek help']
# Row precautions: ['switch to loose cloothing', 'take deep breaths', 'get away from trigger', 'seek help']
# Row precautions: ['switch to loose cloothing', 'take deep breaths', 'get away from trigger', 'seek help']
# Row precautions: ['switch to loose cloothing', 'take deep breaths', 'get away from trigger', 'seek help']
# Row precautions: ['use heating pad or cold pack', 'exercise', 'take otc pain reliver', 'consult doctor']
# Row precautions: ['use heating pad or cold pack', 'exercise', 'take otc pain reliver', 'consult doctor']
# Row precautions: ['use heating pad or cold pack', 'exercise', 'take otc pain reliver', 'consult doctor']
# Row precautions: ['use heating pad or cold pack', 'exercise', 'take otc pain reliver', 'consult doctor']
# Row precautions: ['use heating pad or cold pack', 'exercise', 'take otc pain reliver', 'consult doctor']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['use neem in bathing', 'consume neem leaves', 'take vaccine', 'avoid public places']
# Row precautions: ['cold baths', 'anti itch medicine', 'consult doctor', 'eat healthy']
# Row precautions: ['cold baths', 'anti itch medicine', 'consult doctor', 'eat healthy']
# Row precautions: ['cold baths', 'anti itch medicine', 'consult doctor', 'eat healthy']
# Row precautions: ['cold baths', 'anti itch medicine', 'consult doctor', 'eat healthy']
# Row precautions: ['cold baths', 'anti itch medicine', 'consult doctor', 'eat healthy']
# Row precautions: ['cold baths', 'anti itch medicine', 'consult doctor', 'eat healthy']
# Row precautions: ['cold baths', 'anti itch medicine', 'consult doctor', 'eat healthy']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink vitamin c rich drinks', 'take vapour', 'avoid cold food', 'keep fever in check']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['drink papaya leaf juice', 'avoid fatty spicy food', 'keep mosquitos away', 'keep hydrated']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['have balanced diet', 'exercise', 'consult doctor', 'follow up']
# Row precautions: ['avoid fatty spicy food', 'consume witch hazel', 'warm bath with epsom salt', 'consume alovera juice']
# Row precautions: ['avoid fatty spicy food', 'consume witch hazel', 'warm bath with epsom salt', 'consume alovera juice']
# Row precautions: ['avoid fatty spicy food', 'consume witch hazel', 'warm bath with epsom salt', 'consume alovera juice']
# Row precautions: ['avoid fatty spicy food', 'consume witch hazel', 'warm bath with epsom salt', 'consume alovera juice']
# Row precautions: ['avoid fatty spicy food', 'consume witch hazel', 'warm bath with epsom salt', 'consume alovera juice']
# Row precautions: ['stop irritation', 'consult nearest hospital', 'stop taking drug', 'follow up']
# Row precautions: ['stop irritation', 'consult nearest hospital', 'stop taking drug', 'follow up']
# Row precautions: ['stop irritation', 'consult nearest hospital', 'stop taking drug', 'follow up']
# Row precautions: ['stop irritation', 'consult nearest hospital', 'stop taking drug', 'follow up']
# Row precautions: ['stop irritation', 'consult nearest hospital', 'stop taking drug', 'follow up']
# Row precautions: ['bath twice', 'use detol or neem in bathing water', 'keep infected area dry', 'use clean cloths']
# Row precautions: ['bath twice', 'use detol or neem in bathing water', 'keep infected area dry', 'use clean cloths']
# Row precautions: ['bath twice', 'use detol or neem in bathing water', 'keep infected area dry', 'use clean cloths']
# Row precautions: ['bath twice', 'use detol or neem in bathing water', 'keep infected area dry', 'use clean cloths']
# Row precautions: ['stop eating solid food for while', 'try taking small sips of water', 'rest', 'ease back into eating']
# Row precautions: ['stop eating solid food for while', 'try taking small sips of water', 'rest', 'ease back into eating']
# Row precautions: ['stop eating solid food for while', 'try taking small sips of water', 'rest', 'ease back into eating']
# Row precautions: ['stop eating solid food for while', 'try taking small sips of water', 'rest', 'ease back into eating']
# Row precautions: ['avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'exercise']
# Row precautions: ['avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'exercise']
# Row precautions: ['avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'exercise']
# Row precautions: ['avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'exercise']
# Row precautions: ['avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'exercise']
# Row precautions: ['avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'exercise']
# Row precautions: ['call ambulance', 'chew or swallow asprin', 'keep calm']
# Row precautions: ['call ambulance', 'chew or swallow asprin', 'keep calm']
# Row precautions: ['call ambulance', 'chew or swallow asprin', 'keep calm']
# Row precautions: ['call ambulance', 'chew or swallow asprin', 'keep calm']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'wash hands through', 'avoid fatty spicy food', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult nearest hospital', 'vaccination', 'eat healthy', 'medication']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'eat healthy', 'follow up']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['stop alcohol consumption', 'rest', 'consult doctor', 'medication']
# Row precautions: ['meditation', 'salt baths', 'reduce stress', 'get proper sleep']
# Row precautions: ['meditation', 'salt baths', 'reduce stress', 'get proper sleep']
# Row precautions: ['meditation', 'salt baths', 'reduce stress', 'get proper sleep']
# Row precautions: ['meditation', 'salt baths', 'reduce stress', 'get proper sleep']
# Row precautions: ['meditation', 'salt baths', 'reduce stress', 'get proper sleep']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['eat healthy', 'massage', 'use lemon balm', 'take radioactive iodine treatment']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['lie down on side', 'check in pulse', 'drink sugary drinks', 'consult doctor']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['reduce stress', 'exercise', 'eat healthy', 'get proper sleep']
# Row precautions: ['soak affected area in warm water', 'use antibiotics', 'remove scabs with wet compressed cloth', 'consult doctor']
# Row precautions: ['soak affected area in warm water', 'use antibiotics', 'remove scabs with wet compressed cloth', 'consult doctor']
# Row precautions: ['soak affected area in warm water', 'use antibiotics', 'remove scabs with wet compressed cloth', 'consult doctor']
# Row precautions: ['soak affected area in warm water', 'use antibiotics', 'remove scabs with wet compressed cloth', 'consult doctor']
# Row precautions: ['soak affected area in warm water', 'use antibiotics', 'remove scabs with wet compressed cloth', 'consult doctor']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['drink plenty of water', 'consume milk thistle', 'eat fruits and high fiberous food', 'medication']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['consult nearest hospital', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['meditation', 'reduce stress', 'use poloroid glasses in sun', 'consult doctor']
# Row precautions: ['acetaminophen', 'consult nearest hospital', 'follow up', 'salt baths']
# Row precautions: ['acetaminophen', 'consult nearest hospital', 'follow up', 'salt baths']
# Row precautions: ['acetaminophen', 'consult nearest hospital', 'follow up', 'salt baths']
# Row precautions: ['acetaminophen', 'consult nearest hospital', 'follow up', 'salt baths']
# Row precautions: ['acetaminophen', 'consult nearest hospital', 'follow up', 'salt baths']
# Row precautions: ['acetaminophen', 'consult nearest hospital', 'follow up', 'salt baths']
# Row precautions: ['massage', 'eat healthy', 'exercise', 'consult doctor']
# Row precautions: ['massage', 'eat healthy', 'exercise', 'consult doctor']
# Row precautions: ['massage', 'eat healthy', 'exercise', 'consult doctor']
# Row precautions: ['massage', 'eat healthy', 'exercise', 'consult doctor']
# Row precautions: ['avoid fatty spicy food', 'consume probiotic food', 'eliminate milk', 'limit alcohol']
# Row precautions: ['avoid fatty spicy food', 'consume probiotic food', 'eliminate milk', 'limit alcohol']
# Row precautions: ['avoid fatty spicy food', 'consume probiotic food', 'eliminate milk', 'limit alcohol']
# Row precautions: ['avoid fatty spicy food', 'consume probiotic food', 'eliminate milk', 'limit alcohol']
# Row precautions: ['avoid fatty spicy food', 'consume probiotic food', 'eliminate milk', 'limit alcohol']
# Row precautions: ['avoid fatty spicy food', 'consume probiotic food', 'eliminate milk', 'limit alcohol']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['consult doctor', 'medication', 'rest', 'follow up']
# Row precautions: ['wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths']
# Row precautions: ['wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths']
# Row precautions: ['wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths']
# Row precautions: ['wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths']
# Row precautions: ['wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths']
# Row precautions: ['wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['cover mouth', 'consult doctor', 'medication', 'rest']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['eat high calorie vegitables', 'antiboitic therapy', 'consult doctor', 'medication']
# Row precautions: ['drink plenty of water', 'increase vitamin c intake', 'drink cranberry juice', 'take probiotics']
# Row precautions: ['drink plenty of water', 'increase vitamin c intake', 'drink cranberry juice', 'take probiotics']
# Row precautions: ['drink plenty of water', 'increase vitamin c intake', 'drink cranberry juice', 'take probiotics']
# Row precautions: ['drink plenty of water', 'increase vitamin c intake', 'drink cranberry juice', 'take probiotics']
# Row precautions: ['lie down flat and raise the leg high', 'use oinments', 'use vein compression', 'dont stand still for long']
# Row precautions: ['lie down flat and raise the leg high', 'use oinments', 'use vein compression', 'dont stand still for long']
# Row precautions: ['lie down flat and raise the leg high', 'use oinments', 'use vein compression', 'dont stand still for long']
# Row precautions: ['lie down flat and raise the leg high', 'use oinments', 'use vein compression', 'dont stand still for long']
# Row precautions: ['lie down flat and raise the leg high', 'use oinments', 'use vein compression', 'dont stand still for long']
# Row precautions: ['lie down flat and raise the leg high', 'use oinments', 'use vein compression', 'dont stand still for long']
# Row precautions: ['lie down flat and raise the leg high', 'use oinments', 'use vein compression', 'dont stand still for long']

# %%
# Save to file
symptom_df.to_pickle('../embeddings/symptom_embeddings.pkl')  # Save as pickle for easy reloading
